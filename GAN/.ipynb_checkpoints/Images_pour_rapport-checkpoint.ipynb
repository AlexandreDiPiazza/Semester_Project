# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
datapath = 'trainset/'
name = "final"
x_train = np.load(datapath + name + '_samples_dip_.npy', allow_pickle = True)[:,0]
y_train = np.load(datapath +  name + '_targets_dip_.npy', allow_pickle = True)
hs = np.load(datapath +  name + '_patch_targets_dip_.npy', allow_pickle = True)

# %%
datapath = 'trainset/'
name = "prev_label"
x_train2 = np.load(datapath + name + '_samples64.npy', allow_pickle = True)[:,0]
y_train2 = np.load(datapath +  name + '_targets64.npy', allow_pickle = True)
hs2 = np.load(datapath +  name + '_patch_targets64.npy', allow_pickle = True)

# %%
np.shape(x_train)
# Out:
# (5040, 256, 256)

# %%
# eg : 16, 17, 18, 19 ...  
# rajouter de l'aléatoire, parfois pas de changement, parfois oui
plt.imshow(x_train[106,:,:])

# %%
#np.shape(x_train)

# %%
# eg : 16, 17, 18, 19 ...  
# rajouter de l'aléatoire, parfois pas de changement, parfois oui
#plt.imshow(y_train[14,:,:])

# %%
# eg : 5, 9, 11, 14, 15
#plt.imshow(x_train2[5,:,:])

# %%
#plt.imshow(x_train2[126,:,:])

# %%
import matplotlib
matplotlib.image.imsave('new9.png', x_train[106,:,:])
